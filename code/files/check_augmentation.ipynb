# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from image_data_generator import ImageGenerator

# %%
gen = ImageGenerator()
# Out:
# 100%|██████████| 281/281 [00:03<00:00, 80.50it/s]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
img = gen.read_for_training('0000e88ab.jpg').squeeze()
print(img.shape)
imgplot = plt.imshow(img)
plt.show()
# Out:
# (384, 384)
